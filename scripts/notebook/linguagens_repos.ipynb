# %% [markdown]
# <span style="font-size: 2em;">Conhecendo a requests</span>

# %% [markdown]
# As requisições são pedidos que fazemos a um servidor para que ele nos forneça alguma informação ou execute alguma ação. As requisições mais comuns são:
#
# GET: é a requisição mais utilizada na web e tem como objetivo buscar informações de um servidor. Por exemplo, ao acessar um site de notícias, é realizada uma requisição GET para buscar as informações da página que será exibida.
#
# POST: é utilizada para enviar informações para um servidor e, geralmente, é usada para realizar ações como criar um novo usuário ou enviar dados de um formulário. Ao enviar um e-mail através de um formulário em um site, é realizada uma requisição POST para enviar as informações do formulário ao servidor.
#
# PUT: é usada para substituir completamente um recurso no servidor. Ao enviar uma requisição PUT, você envia todas as informações necessárias para atualizar o recurso por completo, substituindo todos os campos e informações existentes. Por exemplo, ao alterar todas as informações de seu perfil em alguma rede social (nome, foto, interesses, etc), é realizada uma requisição PUT.
#
# DELETE: como o nome sugere, é utilizada para excluir informações em um servidor. Por exemplo, ao excluir um post em uma rede social, é realizada uma requisição DELETE para remover as informações do servidor.
#
# PATCH: é utilizada para fazer alterações parciais em um recurso existente no servidor. Ao enviar uma requisição PATCH, você envia apenas as informações específicas que deseja alterar, mantendo as demais informações do recurso intactas. Por exemplo, ao alterar apenas o status de uma tarefa em um sistema de gerenciamento, de "Em andamento" para "Concluída", é realizada uma requisição PATCH.

# %% [markdown]
# Primeira requisição:

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# <span style="font-size: 2em;">Explorando a biblioteca</span>

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"37789056917","type":"IssueCommentEvent","actor":{"id":30114997,"login":"tszheichoi","display_login":"tszheichoi","gravatar_id":"","url":"https://api.github.com/users/tszheichoi","avatar_url":"https://avatars.githubusercontent.com/u/30114997?"},"repo":{"id":502129301,"name":"tszheichoi/awesome-sensor-logger","url":"https://api.github.com/repos/tszheichoi/awesome-sensor-logger"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34","repository_url":"https://api.github.com/repos/tszheichoi/awesome-sensor-logger","labels_url":"https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34/labels{/name}","comments_url":"https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34/comments","events_url":"https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34/events","html_url":"https://github.com/tszheichoi/awesome-sensor-logger/issues/34","id":2257668466,"node_id":"I_kwDOHe3ilc6GkUly","number":34,"title":"GNSS observables","user":{"login":"kcleineweber","id":29378899,"node_id":"MDQ6VXNlcjI5Mzc4ODk5","avatar_url":"https://avatars.githubusercontent.com/u/29378899?v=4","gravatar_id":"","url":"https://api.github.com/users/kcleineweber","html_url":"https://github.com/kcleineweber","followers_url":"https://api.github.com/users/kcleineweber/followers","following_url":"https://api.github.com/users/kcleineweber/following{/other_user}","gists_url":"https://api.github.com/users/kcleineweber/gists{/gist_id}","starred_url":"https://api.github.com/users/kcleineweber/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/kcleineweber/subscriptions","organizations_url":"https://api.github.com/users/kcleineweber/orgs","repos_url":"https://api.github.com/users/kcleineweber/repos","events_url":"https://api.github.com/users/kcleineweber/events{/privacy}","received_events_url":"https://api.github.com/users/kcleineweber/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":1,"created_at":"2024-04-23T00:12:12Z","updated_at":"2024-04-24T20:41:56Z","closed_at":null,"author_association":"NONE","active_lock_reason":null,"body":"Is it possible to log not only the location solutions but the raw observables - pseudorange, doppler, adr? Thanks","reactions":{"url":"https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34/reactions","total_count":0,"+1":0,"-1":0,"laugh":0,"hooray":0,"confused":0,"heart":0,"rocket":0,"eyes":0},"timeline_url":"https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34/timeline","performed_via_github_app":null,"state_reason":null},"comment":{"url":"https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/comments/2075805538","html_url":"https://github.com/tszheichoi/awesome-sensor-logger/issues/34#issuecomment-2075805538","issue_url":"https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34","id":2075805538,"node_id":"IC_kwDOHe3ilc57ukdi","user":{"login":"tszheichoi","id":30114997,"node_id":"MDQ6VXNlcjMwMTE0OTk3","avatar_url":"https://avatars.githubusercontent.com/u/30114997?v=4","gravatar_id":"","url":"https://api.github.com/users/tszheichoi","html_url":"https://github.com/tszheichoi","followers_url":"https://api.github.com/users/tszheichoi/followers","following_url":"https://api.github.com/users/tszheichoi/following{/other_user}","gists_url":"https://api.github.com/users/tszheichoi/gists{/gist_id}","starred_url":"https://api.github.com/users/tszheichoi/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/tszheichoi/subscriptions","organizations_url":"https://api.github.com/users/tszheichoi/orgs","repos_url":"https://api.github.com/users/tszheichoi/repos","events_url":"https://api.github.com/users/tszheichoi/events{/privacy}","received_events_url":"https://api.github.com/users/tszheichoi/received_events","type":"User","site_admin":fal ...

# %%
r.json()
# Out:
# [{'id': '37789056917',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 30114997,
#    'login': 'tszheichoi',
#    'display_login': 'tszheichoi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tszheichoi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30114997?'},
#   'repo': {'id': 502129301,
#    'name': 'tszheichoi/awesome-sensor-logger',
#    'url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34',
#     'repository_url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger',
#     'labels_url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34/comments',
#     'events_url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34/events',
#     'html_url': 'https://github.com/tszheichoi/awesome-sensor-logger/issues/34',
#     'id': 2257668466,
#     'node_id': 'I_kwDOHe3ilc6GkUly',
#     'number': 34,
#     'title': 'GNSS observables',
#     'user': {'login': 'kcleineweber',
#      'id': 29378899,
#      'node_id': 'MDQ6VXNlcjI5Mzc4ODk5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/29378899?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/kcleineweber',
#      'html_url': 'https://github.com/kcleineweber',
#      'followers_url': 'https://api.github.com/users/kcleineweber/followers',
#      'following_url': 'https://api.github.com/users/kcleineweber/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/kcleineweber/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/kcleineweber/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/kcleineweber/subscriptions',
#      'organizations_url': 'https://api.github.com/users/kcleineweber/orgs',
#      'repos_url': 'https://api.github.com/users/kcleineweber/repos',
#      'events_url': 'https://api.github.com/users/kcleineweber/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/kcleineweber/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2024-04-23T00:12:12Z',
#     'updated_at': '2024-04-24T20:41:56Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'Is it possible to log not only the location solutions but the raw observables - pseudorange, doppler, adr? Thanks',
#     'reactions': {'url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/comments/2075805538',
#     'html_url': 'https://github.com/tszheichoi/awesome-sensor-logger/issues/34#issuecomment-2075805538',
#     'issue_url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/34',
#     'id': 2075805538,
#     'node_id': 'IC_kwDOHe3ilc57ukdi',
#     'user': {'login': 'tszheichoi',
#      'id': 30114997,
#      'node_id': 'MDQ6VXNlcjMwMTE0OTk3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/30114997?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tszheichoi',
#      'html_url': 'https://github.com/tszheichoi',
#      'followers_url': 'https://api.github.com/users/tszheichoi/followers',
#      'following_url': 'https://api.github.com/users/tszheichoi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tszheichoi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tszheichoi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tszheichoi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tszheichoi/orgs',
#      'repos_url': 'https://api.github.com/users/tszheichoi/repos',
#      'events_url': 'https://api.github.com/users/tszheichoi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tszheichoi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2024-04-24T20:41:55Z',
#     'updated_at': '2024-04-24T20:41:55Z',
#     'author_association': 'OWNER',
#     'body': 'Sensor Logger currently does not support these raw values, primarily because it is not available on iOS, and I want most features to be reasonably cross-platform. See, for example, https://developer.apple.com/forums/thread/693229. On the other hand, I believe it is technically possible on Android. Are there particular reasons / use cases you want to achieve with these? If so, happy to consider implementing. ',
#     'reactions': {'url': 'https://api.github.com/repos/tszheichoi/awesome-sensor-logger/issues/comments/2075805538/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056814',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 43480880,
#    'login': 'linux-foundation-easycla[bot]',
#    'display_login': 'linux-foundation-easycla',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/linux-foundation-easycla[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43480880?'},
#   'repo': {'id': 12223350,
#    'name': 'cloudfoundry/cli',
#    'url': 'https://api.github.com/repos/cloudfoundry/cli'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/cloudfoundry/cli/issues/2858',
#     'repository_url': 'https://api.github.com/repos/cloudfoundry/cli',
#     'labels_url': 'https://api.github.com/repos/cloudfoundry/cli/issues/2858/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/cloudfoundry/cli/issues/2858/comments',
#     'events_url': 'https://api.github.com/repos/cloudfoundry/cli/issues/2858/events',
#     'html_url': 'https://github.com/cloudfoundry/cli/pull/2858',
#     'id': 2262149299,
#     'node_id': 'PR_kwDOALqDds5tphnq',
#     'number': 2858,
#     'title': 'Add "total_domains" to quota json unmarshalling',
#     'user': {'login': 'sleungcy-sap',
#      'id': 153762844,
#      'node_id': 'U_kgDOCSo8HA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/153762844?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sleungcy-sap',
#      'html_url': 'https://github.com/sleungcy-sap',
#      'followers_url': 'https://api.github.com/users/sleungcy-sap/followers',
#      'following_url': 'https://api.github.com/users/sleungcy-sap/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sleungcy-sap/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sleungcy-sap/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sleungcy-sap/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sleungcy-sap/orgs',
#      'repos_url': 'https://api.github.com/users/sleungcy-sap/repos',
#      'events_url': 'https://api.github.com/users/sleungcy-sap/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sleungcy-sap/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2024-04-24T20:41:50Z',
#     'updated_at': '2024-04-24T20:41:56Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/cloudfoundry/cli/pulls/2858',
#      'html_url': 'https://github.com/cloudfoundry/cli/pull/2858',
#      'diff_url': 'https://github.com/cloudfoundry/cli/pull/2858.diff',
#      'patch_url': 'https://github.com/cloudfoundry/cli/pull/2858.patch',
#      'merged_at': None},
#     'body': "Thank you for contributing to the CF CLI! Please read the following:\r\n\r\n\r\n* Please make sure you have implemented changes in line with the [contributing guidelines](https://github.com/cloudfoundry/cli/blob/main/.github/CONTRIBUTING.md)\r\n* We're not allowed to accept any PRs without a signed CLA, no matter how small.\r\nIf your contribution falls under a company CLA but your membership is not public, expect delays while we confirm.\r\n* All new code requires tests to protect against regressions.\r\n* Contributions must be made against the appropriate branch. See the [contributing guidelines](https://github.com/cloudfoundry/cli/blob/main/.github/CONTRIBUTING.md)\r\n* Contributions must conform to our [style guide](https://github.com/cloudfoundry/cli/wiki/CLI-Product-Specific-Style-Guide). Please reach out to us if you have questions.\r\n\r\n\r\n## Where this PR should be backported?\r\n\r\n- [ ] [main](https://github.com/cloudfoundry/cli/tree/main) - all changes should by default start here\r\n- [ ] [v8](https://github.com/cloudfoundry/cli/tree/v8)\r\n- [ ] [v7](https://github.com/cloudfoundry/cli/tree/v7)\r\n\r\n## Description of the Change\r\n\r\nWe must be able to understand the design of your change from this description.\r\nKeep in mind that the maintainer reviewing this PR may not be familiar with or\r\nhave worked with the code here recently, so please walk us through the concepts.\r\n\r\n\r\n## Why Is This PR Valuable?\r\n\r\nWhat benefits will be realized by the code change? What users would want this change? What user need is this change addressing? \r\n\r\n## Applicable Issues\r\n\r\nList any applicable GitHub Issues here\r\n\r\n## How Urgent Is The Change?\r\n\r\nIs the change urgent? If so, explain why it is time-sensitive.\r\n\r\n## Other Relevant Parties\r\n\r\nWho else is affected by the change? \r\n",
#     'reactions': {'url': 'https://api.github.com/repos/cloudfoundry/cli/issues/2858/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/cloudfoundry/cli/issues/2858/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/cloudfoundry/cli/issues/comments/2075805528',
#     'html_url': 'https://github.com/cloudfoundry/cli/pull/2858#issuecomment-2075805528',
#     'issue_url': 'https://api.github.com/repos/cloudfoundry/cli/issues/2858',
#     'id': 2075805528,
#     'node_id': 'IC_kwDOALqDds57ukdY',
#     'user': {'login': 'linux-foundation-easycla[bot]',
#      'id': 43480880,
#      'node_id': 'MDM6Qm90NDM0ODA4ODA=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/17893?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/linux-foundation-easycla%5Bbot%5D',
#      'html_url': 'https://github.com/apps/linux-foundation-easycla',
#      'followers_url': 'https://api.github.com/users/linux-foundation-easycla%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/linux-foundation-easycla%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/linux-foundation-easycla%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/linux-foundation-easycla%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/linux-foundation-easycla%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/linux-foundation-easycla%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/linux-foundation-easycla%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/linux-foundation-easycla%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/linux-foundation-easycla%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2024-04-24T20:41:55Z',
#     'updated_at': '2024-04-24T20:41:55Z',
#     'author_association': 'NONE',
#     'body': ' <a href="https://api.easycla.lfx.linuxfoundation.org/v2/repository-provider/github/sign/1797134/12223350/2858/#/?version=2"><img src="https://s3.amazonaws.com/cla-project-logo-prod/cla-not-signed.svg" alt="CLA Not Signed" align="left" height="28" width="328"></a><br/><br /><ul><li><a href=\'https://api.easycla.lfx.linuxfoundation.org/v2/repository-provider/github/sign/1797134/12223350/2858/#/?version=2\' target=\'_blank\'>:x:</a> - login: @sleungcy-sap / name: Sam Leung . The commit (29801d83de95921bccd966e45c4257cd9a2e726e) is not authorized under a signed CLA. <a href=\'https://api.easycla.lfx.linuxfoundation.org/v2/repository-provider/github/sign/1797134/12223350/2858/#/?version=2\' target=\'_blank\'>Please click here to be authorized</a>. For further assistance with EasyCLA, <a href=\'https://jira.linuxfoundation.org/servicedesk/customer/portal/4\' target=\'_blank\'>please submit a support request ticket</a>.</li></ul>',
#     'reactions': {'url': 'https://api.github.com/repos/cloudfoundry/cli/issues/comments/2075805528/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': {'id': 17893,
#      'slug': 'linux-foundation-easycla',
#      'node_id': 'MDM6QXBwMTc4OTM=',
#      'owner': {'login': 'LF-Engineering',
#       'id': 38015056,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4MDE1MDU2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/38015056?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/LF-Engineering',
#       'html_url': 'https://github.com/LF-Engineering',
#       'followers_url': 'https://api.github.com/users/LF-Engineering/followers',
#       'following_url': 'https://api.github.com/users/LF-Engineering/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/LF-Engineering/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/LF-Engineering/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/LF-Engineering/subscriptions',
#       'organizations_url': 'https://api.github.com/users/LF-Engineering/orgs',
#       'repos_url': 'https://api.github.com/users/LF-Engineering/repos',
#       'events_url': 'https://api.github.com/users/LF-Engineering/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/LF-Engineering/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'name': 'Linux Foundation: EasyCLA',
#      'description': 'The Contributor License Agreement (CLA) service of the Linux Foundation lets project contributors read, sign, and submit license agreements easily.',
#      'external_url': 'https://www.linuxfoundation.org/',
#      'html_url': 'https://github.com/apps/linux-foundation-easycla',
#      'created_at': '2018-09-21T18:36:19Z',
#      'updated_at': '2020-11-07T20:38:10Z',
#      'permissions': {'administration': 'write',
#       'emails': 'read',
#       'issues': 'read',
#       'members': 'read',
#       'metadata': 'read',
#       'pull_requests': 'write',
#       'repository_hooks': 'write',
#       'statuses': 'write'},
#      'events': ['issue_comment',
#       'pull_request',
#       'pull_request_review',
#       'pull_request_review_comment',
#       'repository',
#       'status']}}},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z',
#   'org': {'id': 621746,
#    'login': 'cloudfoundry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudfoundry',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/621746?'}},
#  {'id': '37789056798',
#   'type': 'PushEvent',
#   'actor': {'id': 3263627,
#    'login': 'pmacik',
#    'display_login': 'pmacik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pmacik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3263627?'},
#   'repo': {'id': 791501254,
#    'name': 'pmacik-testing/pr3616-0075-0058-app-ykgKh-burst-pray',
#    'url': 'https://api.github.com/repos/pmacik-testing/pr3616-0075-0058-app-ykgKh-burst-pray'},
#   'payload': {'repository_id': 791501254,
#    'push_id': 18145227198,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/main',
#    'head': 'dac40f3197fd4592cfe14a424b92342328d64542',
#    'before': '0000000000000000000000000000000000000000',
#    'commits': [{'sha': 'dac40f3197fd4592cfe14a424b92342328d64542',
#      'author': {'email': '95716864+appstudio-appdata-bot@users.noreply.github.com',
#       'name': 'AppData Robot'},
#      'message': 'Generating GitOps resources',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/pmacik-testing/pr3616-0075-0058-app-ykgKh-burst-pray/commits/dac40f3197fd4592cfe14a424b92342328d64542'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z',
#   'org': {'id': 58070390,
#    'login': 'pmacik-testing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pmacik-testing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58070390?'}},
#  {'id': '37789056853',
#   'type': 'PushEvent',
#   'actor': {'id': 77333988,
#    'login': 'Guillei',
#    'display_login': 'Guillei',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Guillei',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77333988?'},
#   'repo': {'id': 784792900,
#    'name': 'Guillei/tu',
#    'url': 'https://api.github.com/repos/Guillei/tu'},
#   'payload': {'repository_id': 784792900,
#    'push_id': 18145227221,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b068afdf6cb845fcb073ae07f33006aea69cdb7b',
#    'before': '2e51e3430ad12365f3177aadfb6a31033a69d9b1',
#    'commits': [{'sha': 'b068afdf6cb845fcb073ae07f33006aea69cdb7b',
#      'author': {'email': '77333988+Guillei@users.noreply.github.com',
#       'name': 'Guillei'},
#      'message': 'Upload screenshot',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Guillei/tu/commits/b068afdf6cb845fcb073ae07f33006aea69cdb7b'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056862',
#   'type': 'CreateEvent',
#   'actor': {'id': 3263627,
#    'login': 'pmacik',
#    'display_login': 'pmacik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pmacik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3263627?'},
#   'repo': {'id': 791501363,
#    'name': 'pmacik-testing/pr3616-0075-0039-app-K8lbf-beat-cry',
#    'url': 'https://api.github.com/repos/pmacik-testing/pr3616-0075-0039-app-K8lbf-beat-cry'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'GitOps Repository',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z',
#   'org': {'id': 58070390,
#    'login': 'pmacik-testing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pmacik-testing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58070390?'}},
#  {'id': '37789056854',
#   'type': 'PushEvent',
#   'actor': {'id': 9280991,
#    'login': 'RBEGamer',
#    'display_login': 'RBEGamer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RBEGamer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9280991?'},
#   'repo': {'id': 671078235,
#    'name': 'RBEGamer/MixMeasureBuddy',
#    'url': 'https://api.github.com/repos/RBEGamer/MixMeasureBuddy'},
#   'payload': {'repository_id': 671078235,
#    'push_id': 18145227218,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c7c3ad6e59f778ed01d921c58e78a3feb26ee6f0',
#    'before': 'd8eb49abb6789fc8d4bcfcaf66876e3880fe15bb',
#    'commits': [{'sha': 'c7c3ad6e59f778ed01d921c58e78a3feb26ee6f0',
#      'author': {'email': 'marcel.ochsendorf@gmail.com',
#       'name': 'Marcel Ochsendorf'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RBEGamer/MixMeasureBuddy/commits/c7c3ad6e59f778ed01d921c58e78a3feb26ee6f0'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056849',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 335401193,
#    'name': 'chrislkeller/nm-vaccine-data',
#    'url': 'https://api.github.com/repos/chrislkeller/nm-vaccine-data'},
#   'payload': {'repository_id': 335401193,
#    'push_id': 18145227220,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '85bd5697c1021e57bf71cf21895ff96ec7768425',
#    'before': 'fed4992f2dbf5a09f8b6a4734630db1006256637',
#    'commits': [{'sha': '85bd5697c1021e57bf71cf21895ff96ec7768425',
#      'author': {'email': 'christopherlawrencekeller@gmail.com',
#       'name': 'chrislkeller'},
#      'message': 'Updates with the latest county-level json data: Wed Apr 24 20:41:54 UTC 2024',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chrislkeller/nm-vaccine-data/commits/85bd5697c1021e57bf71cf21895ff96ec7768425'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056845',
#   'type': 'PushEvent',
#   'actor': {'id': 136290555,
#    'login': 'rgnq520',
#    'display_login': 'rgnq520',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rgnq520',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136290555?'},
#   'repo': {'id': 652415518,
#    'name': 'rgnq520/wzaz259',
#    'url': 'https://api.github.com/repos/rgnq520/wzaz259'},
#   'payload': {'repository_id': 652415518,
#    'push_id': 18145227230,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': 'f27050390ed87ca971177a56bb304fed150403ff',
#    'before': '4c4cd0131b3b86bf91a194675aaca23564964265',
#    'commits': [{'sha': 'f27050390ed87ca971177a56bb304fed150403ff',
#      'author': {'email': 'example@email.com', 'name': 'wzaz259'},
#      'message': 'A custom message for the commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rgnq520/wzaz259/commits/f27050390ed87ca971177a56bb304fed150403ff'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056863',
#   'type': 'PushEvent',
#   'actor': {'id': 112548604,
#    'login': 'Elgedawy31',
#    'display_login': 'Elgedawy31',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Elgedawy31',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112548604?'},
#   'repo': {'id': 783656303,
#    'name': 'Elgedawy31/nobel',
#    'url': 'https://api.github.com/repos/Elgedawy31/nobel'},
#   'payload': {'repository_id': 783656303,
#    'push_id': 18145227232,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b576652b5091578200b120c8a5515497802037e0',
#    'before': '8b1e1aeb2a0fee7ad4f9104900a60cc79266dd9d',
#    'commits': [{'sha': 'b576652b5091578200b120c8a5515497802037e0',
#      'author': {'email': 'mohamedelgedawy40@gmail.com', 'name': 'Elgedawy31'},
#      'message': 'updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Elgedawy31/nobel/commits/b576652b5091578200b120c8a5515497802037e0'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056842',
#   'type': 'PushEvent',
#   'actor': {'id': 17571478,
#    'login': 'Domiciano',
#    'display_login': 'Domiciano',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Domiciano',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17571478?'},
#   'repo': {'id': 790778420,
#    'name': 'Domiciano/PracticaSemestre1',
#    'url': 'https://api.github.com/repos/Domiciano/PracticaSemestre1'},
#   'payload': {'repository_id': 790778420,
#    'push_id': 18145227216,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd1a4878d0884beb394a5fd3014499423a0e53cd9',
#    'before': 'aa5f4a4bbff239fa2be08e3102de63445e002733',
#    'commits': [{'sha': 'd1a4878d0884beb394a5fd3014499423a0e53cd9',
#      'author': {'email': 'domiciano.rincon@correounivalle.edu.co',
#       'name': 'Domiciano Rincón'},
#      'message': 'Map created',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Domiciano/PracticaSemestre1/commits/d1a4878d0884beb394a5fd3014499423a0e53cd9'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056828',
#   'type': 'CreateEvent',
#   'actor': {'id': 168021597,
#    'login': 'Matthewidiroy',
#    'display_login': 'Matthewidiroy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Matthewidiroy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/168021597?'},
#   'repo': {'id': 791501362,
#    'name': 'Matthewidiroy/HomeCookingSystem',
#    'url': 'https://api.github.com/repos/Matthewidiroy/HomeCookingSystem'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'RecipeApp',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056890',
#   'type': 'IssuesEvent',
#   'actor': {'id': 72635603,
#    'login': 'TWCCarlson',
#    'display_login': 'TWCCarlson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TWCCarlson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72635603?'},
#   'repo': {'id': 538318453,
#    'name': 'ScreteMonge/3D-Weather',
#    'url': 'https://api.github.com/repos/ScreteMonge/3D-Weather'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/ScreteMonge/3D-Weather/issues/32',
#     'repository_url': 'https://api.github.com/repos/ScreteMonge/3D-Weather',
#     'labels_url': 'https://api.github.com/repos/ScreteMonge/3D-Weather/issues/32/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ScreteMonge/3D-Weather/issues/32/comments',
#     'events_url': 'https://api.github.com/repos/ScreteMonge/3D-Weather/issues/32/events',
#     'html_url': 'https://github.com/ScreteMonge/3D-Weather/issues/32',
#     'id': 2254733779,
#     'node_id': 'I_kwDOIBYWdc6GZIHT',
#     'number': 32,
#     'title': 'Client lockup when moving to new (underground) areas',
#     'user': {'login': 'TWCCarlson',
#      'id': 72635603,
#      'node_id': 'MDQ6VXNlcjcyNjM1NjAz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/72635603?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/TWCCarlson',
#      'html_url': 'https://github.com/TWCCarlson',
#      'followers_url': 'https://api.github.com/users/TWCCarlson/followers',
#      'following_url': 'https://api.github.com/users/TWCCarlson/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/TWCCarlson/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/TWCCarlson/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/TWCCarlson/subscriptions',
#      'organizations_url': 'https://api.github.com/users/TWCCarlson/orgs',
#      'repos_url': 'https://api.github.com/users/TWCCarlson/repos',
#      'events_url': 'https://api.github.com/users/TWCCarlson/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/TWCCarlson/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 7,
#     'created_at': '2024-04-20T21:44:59Z',
#     'updated_at': '2024-04-24T20:41:56Z',
#     'closed_at': '2024-04-24T20:41:55Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'Hello,\r\n\r\nI\'ve really enjoyed this plugin for a long time and typically always leave it on. While doing clues recently I started to run into client freezes:\r\n![image](https://github.com/ScreteMonge/3D-Weather/assets/72635603/21d3f385-a1e4-46a4-b61c-fe9d1718ce7c)\r\n\r\nThe game stops rendering and seems un-interactable, even when toggling the GPU plugin.\r\n\r\nI found I was able to consistently recreate this by using the minecart from the GE to Keldagrim, but not in RuneLite safe mode. Iterating through my plugin hub plugins, I found 3D Weather to be the consistent problem. Seems to be independent of the GPU plugin being on or off.\r\n\r\nIt seemed to only happen when transitioning from the overworld to an underground area, as I can cause a freeze going from GE to Keldagrim, or from Edgeville to Edgeville dungeon, but not the other way around. These are my settings for the plugin (I like rain sounds):\r\n![image](https://github.com/ScreteMonge/3D-Weather/assets/72635603/be38722d-42b5-4499-9fa6-7ba75b7d7297)\r\n\r\nWith "Disable Weather Underground" unticked however, I don\'t find any issues.\r\n\r\nIt seems to have to do with the weather type setting. These ones cause the client to freeze:\r\n- Stormy\r\n- Snowy\r\n- Rainy\r\n\r\nInterestingly, ashfall doesn\'t cause any problems despite being another one-tile effect (I did enable it to test).\r\n\r\nHappy to provide any more info that could be of help.',
#     'reactions': {'url': 'https://api.github.com/repos/ScreteMonge/3D-Weather/issues/32/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/ScreteMonge/3D-Weather/issues/32/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'not_planned'}},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056802',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1804568,
#    'login': 'thaJeztah',
#    'display_login': 'thaJeztah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thaJeztah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1804568?'},
#   'repo': {'id': 46089560,
#    'name': 'containerd/containerd',
#    'url': 'https://api.github.com/repos/containerd/containerd'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/containerd/containerd/issues/10123',
#     'repository_url': 'https://api.github.com/repos/containerd/containerd',
#     'labels_url': 'https://api.github.com/repos/containerd/containerd/issues/10123/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/containerd/containerd/issues/10123/comments',
#     'events_url': 'https://api.github.com/repos/containerd/containerd/issues/10123/events',
#     'html_url': 'https://github.com/containerd/containerd/pull/10123',
#     'id': 2259866050,
#     'node_id': 'PR_kwDOAr9FWM5th0et',
#     'number': 10123,
#     'title': 'apparmor: Allow confined runc to kill containers',
#     'user': {'login': 'woky',
#      'id': 620147,
#      'node_id': 'MDQ6VXNlcjYyMDE0Nw==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/620147?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/woky',
#      'html_url': 'https://github.com/woky',
#      'followers_url': 'https://api.github.com/users/woky/followers',
#      'following_url': 'https://api.github.com/users/woky/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/woky/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/woky/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/woky/subscriptions',
#      'organizations_url': 'https://api.github.com/users/woky/orgs',
#      'repos_url': 'https://api.github.com/users/woky/repos',
#      'events_url': 'https://api.github.com/users/woky/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/woky/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 347599644,
#       'node_id': 'MDU6TGFiZWwzNDc1OTk2NDQ=',
#       'url': 'https://api.github.com/repos/containerd/containerd/labels/impact/changelog',
#       'name': 'impact/changelog',
#       'color': 'bfe5bf',
#       'default': False,
#       'description': None},
#      {'id': 2359794839,
#       'node_id': 'MDU6TGFiZWwyMzU5Nzk0ODM5',
#       'url': 'https://api.github.com/repos/containerd/containerd/labels/ok-to-test',
#       'name': 'ok-to-test',
#       'color': 'ededed',
#       'default': False,
#       'description': None},
#      {'id': 3847931915,
#       'node_id': 'LA_kwDOAr9FWM7lWsgL',
#       'url': 'https://api.github.com/repos/containerd/containerd/labels/cherry-pick/1.6.x',
#       'name': 'cherry-pick/1.6.x',
#       'color': 'f90400',
#       'default': False,
#       'description': 'Change to be cherry picked to release/1.6 branch'},
#      {'id': 5250757365,
#       'node_id': 'LA_kwDOAr9FWM8AAAABOPgy9Q',
#       'url': 'https://api.github.com/repos/containerd/containerd/labels/cherry-pick/1.7.x',
#       'name': 'cherry-pick/1.7.x',
#       'color': 'f90400',
#       'default': False,
#       'description': 'Change to be cherry picked to release/1.7 branch'},
#      {'id': 6264155305,
#       'node_id': 'LA_kwDOAr9FWM8AAAABdV9sqQ',
#       'url': 'https://api.github.com/repos/containerd/containerd/labels/size/XS',
#       'name': 'size/XS',
#       'color': '0E8A16',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 10,
#     'created_at': '2024-04-23T22:14:09Z',
#     'updated_at': '2024-04-24T20:41:56Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/containerd/containerd/pulls/10123',
#      'html_url': 'https://github.com/containerd/containerd/pull/10123',
#      'diff_url': 'https://github.com/containerd/containerd/pull/10123.diff',
#      'patch_url': 'https://github.com/containerd/containerd/pull/10123.patch',
#      'merged_at': None},
#     'body': '/usr/sbin/runc is confined with "runc" profile[1] introduced in AppArmor v4.0.0. This change breaks stopping of containers, because the profile assigned to containers doesn\'t accept signals from the "runc" peer. AppArmor >= v4.0.0 is currently part of Ubuntu Mantic (23.10) and later.\r\n\r\nThe issue is reproducible both with nerdctl and ctr clients. In the case of ctr, the --apparmor-default-profile flag has to be specified, otherwise the container processes would inherit the runc profile, which behaves as unconfined, and so the subsequent runc process invoked to stop it would be able to signal it.\r\n\r\n  Test commands:\r\n\r\n    root@cloudimg:~# nerdctl run -d --name foo nginx:latest\r\n    3d1e74bfe6e7b2912d9223050ae8a81a8f4b73de0846e6d9c956c1e411cdd95a\r\n    root@cloudimg:~# nerdctl stop foo\r\n    FATA[0000] 1 errors:\r\n    unknown error after kill: runc did not terminate successfully: exit status 1: unable to signal init: permission denied\r\n    : unknown\r\n\r\n    or\r\n\r\n    root@cloudimg:~# ctr pull docker.io/library/nginx:latest\r\n    ...\r\n    root@cloudimg:~# ctr run -d --apparmor-default-profile ctr-default docker.io/library/nginx:latest foo\r\n    root@cloudimg:~# ctr task kill foo\r\n    ctr: unknown error after kill: runc did not terminate successfully: exit status 1: unable to signal init: permission denied\r\n    : unknown\r\n\r\n  Relevant syslog messages (with long lines wrapped):\r\n\r\n    Apr 23 22:03:12 cloudimg kernel: audit:\r\n      type=1400 audit(1713909792.064:262): apparmor="DENIED"\r\n      operation="signal" class="signal" profile="nerdctl-default"\r\n      pid=13483 comm="runc" requested_mask="receive"\r\n      denied_mask="receive" signal=quit peer="runc"\r\n\r\n    or\r\n\r\n    Apr 23 22:05:32 cloudimg kernel: audit:\r\n      type=1400 audit(1713909932.106:263): apparmor="DENIED"\r\n      operation="signal" class="signal" profile="ctr-default"\r\n      pid=13574 comm="runc" requested_mask="receive"\r\n      denied_mask="receive" signal=quit peer="runc"\r\n\r\nThis change extends the default profile with rules that allow receiving signals from processes that run confined with either runc or crun profile (crun[2] is an alternative OCI runtime that\'s also confined in AppArmor >= v4.0.0, see [1]). It is backward compatible because the peer value is a regular expression (AARE) so the referenced profile doesn\'t have to exist for this profile to successfully compile and load.\r\n\r\n[1] https://gitlab.com/apparmor/apparmor/-/commit/2594d936\r\n[2] https://github.com/containers/crun',
#     'reactions': {'url': 'https://api.github.com/repos/containerd/containerd/issues/10123/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/containerd/containerd/issues/10123/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/containerd/containerd/issues/comments/2075805533',
#     'html_url': 'https://github.com/containerd/containerd/pull/10123#issuecomment-2075805533',
#     'issue_url': 'https://api.github.com/repos/containerd/containerd/issues/10123',
#     'id': 2075805533,
#     'node_id': 'IC_kwDOAr9FWM57ukdd',
#     'user': {'login': 'thaJeztah',
#      'id': 1804568,
#      'node_id': 'MDQ6VXNlcjE4MDQ1Njg=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1804568?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/thaJeztah',
#      'html_url': 'https://github.com/thaJeztah',
#      'followers_url': 'https://api.github.com/users/thaJeztah/followers',
#      'following_url': 'https://api.github.com/users/thaJeztah/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/thaJeztah/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/thaJeztah/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/thaJeztah/subscriptions',
#      'organizations_url': 'https://api.github.com/users/thaJeztah/orgs',
#      'repos_url': 'https://api.github.com/users/thaJeztah/repos',
#      'events_url': 'https://api.github.com/users/thaJeztah/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/thaJeztah/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2024-04-24T20:41:55Z',
#     'updated_at': '2024-04-24T20:41:55Z',
#     'author_association': 'MEMBER',
#     'body': 'Yes, I have no _strong_ objections, if this is urgently needed, but ultimately this would only affect containerd packages as packaged by Ubuntu / Debian, so could be a patch on their side.\r\n\r\nI\'ve written a longer comment on the Moby ticket; https://github.com/moby/moby/pull/47749#issuecomment-2075139545 (quote below)\r\n\r\n<details>\r\n\r\n> So, perhaps a very silly question, as I don\'t know what the common approach is for this, but those profiles are now added to the apparmor package, on behalf of other packages (like `runc` and `crun`). Are such changes considered to be temporary solutions (i.e., `runc` itself doesn\'t install a profile, so the `apparmor` package creates a stub), and should the "northern star" here be for `runc` itself to be installing the profile?\r\n>\r\n> Also asking that, because the profile added is packaging-specific; canonical packaging it separate _and_ using a different location (`sbin` vs `bin`), which to some extent would make it feel more natural to have the profile also included in the `runc` (and `crun`) package; allowing it to define the profile with the correct location of the binary (if installed).\r\n>\r\n> In that situation, Docker (and other packagers) can ship the appropriate profile for _their_ packages (with the location they choose to use for the binary), without `apparmor` trying to guess / detect if it\'s installed.\r\n>\r\n> To some extent it could even be considered for the canonical packages of `docker` to have the profile adjusted to match the other changes, but mostly curious what common procedure is for these\r\n>\r\n> More generally, I wonder if a generic `peer` is something that would be possible (e.g. `oci-runtime`); based on the linked changes, it looks like it\'s possible that "other" runtimes will also get assigned their own, and I think we also want to avoid having to adjust the profile in this repository with an unbounded list of "possible" runtimes that exist.\r\n\r\n</details>\r\n\r\nI guess (if possible);\r\n\r\n- Perhaps the profile should be included in the `runc` and `crun` packages (instead of the AppArmor package trying to detect presence of binaries); this would also take the guesswork out, and make sure `crun` or `runc` (or others) \r\n- Still curious if these binaries should / could have a more generic way (i.e. `peer=oci-runtime` instead of `peer=runc|crun`); can they have _both_? I\'m not deeply familiar with what\'s possible here, but curious if there could be a "generic" way (any `oci-runtime` can do this), but also keep the more specific ones (if specific rules must be applied for specific ones)\r\n- If a `oci-runtime` one could be used, this could (potentially?) allow for the profile to be tightened up; considering that the `unconfined` can be removed, and an `oci-runtime` profile must be present for any runtime that\'s to be used?\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/containerd/containerd/issues/comments/2075805533/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z',
#   'org': {'id': 14037953,
#    'login': 'containerd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/containerd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14037953?'}},
#  {'id': '37789056769',
#   'type': 'PushEvent',
#   'actor': {'id': 54816060,
#    'login': 'pytorch-bot[bot]',
#    'display_login': 'pytorch-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pytorch-bot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54816060?'},
#   'repo': {'id': 454479855,
#    'name': 'pytorch/rl',
#    'url': 'https://api.github.com/repos/pytorch/rl'},
#   'payload': {'repository_id': 454479855,
#    'push_id': 18145227180,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/tags/ciflow/docs/2108',
#    'head': '0000000000000000000000000000000000000000',
#    'before': 'e7988820bd155071aca5de9b14609a4b0b51a0e4',
#    'commits': []},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z',
#   'org': {'id': 21003710,
#    'login': 'pytorch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pytorch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21003710?'}},
#  {'id': '37789056767',
#   'type': 'PushEvent',
#   'actor': {'id': 59054971,
#    'login': 'bittumon',
#    'display_login': 'bittumon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bittumon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59054971?'},
#   'repo': {'id': 718640257,
#    'name': 'bittumon/iveco',
#    'url': 'https://api.github.com/repos/bittumon/iveco'},
#   'payload': {'repository_id': 718640257,
#    'push_id': 18145227182,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e6f9536e053870555d3767410cf52a99013d5322',
#    'before': '4ec03e657265b314d05e19ab58bb423b9add9f73',
#    'commits': [{'sha': 'e6f9536e053870555d3767410cf52a99013d5322',
#      'author': {'email': '59054971+bittumon@users.noreply.github.com',
#       'name': 'Bitz'},
#      'message': 'Update HTML file 2024-04-24 22:33:50',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bittumon/iveco/commits/e6f9536e053870555d3767410cf52a99013d5322'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056721',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 732012147,
#    'name': 'tomb003/yt',
#    'url': 'https://api.github.com/repos/tomb003/yt'},
#   'payload': {'repository_id': 732012147,
#    'push_id': 18145227171,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/y5',
#    'head': '8c842c17b8e1724184dacb50748f0eda68030b7f',
#    'before': '377c6d5b9922035b79c68838b0665cf7a5eb9201',
#    'commits': [{'sha': '8c842c17b8e1724184dacb50748f0eda68030b7f',
#      'author': {'email': 'action@github.com', 'name': 'actions'},
#      'message': 'Update y5',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tomb003/yt/commits/8c842c17b8e1724184dacb50748f0eda68030b7f'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056714',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 44273428,
#    'login': 'amirhosein-vedadi',
#    'display_login': 'amirhosein-vedadi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amirhosein-vedadi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44273428?'},
#   'repo': {'id': 38464245,
#    'name': 'termux/termux-api',
#    'url': 'https://api.github.com/repos/termux/termux-api'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/termux/termux-api/issues/466',
#     'repository_url': 'https://api.github.com/repos/termux/termux-api',
#     'labels_url': 'https://api.github.com/repos/termux/termux-api/issues/466/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/termux/termux-api/issues/466/comments',
#     'events_url': 'https://api.github.com/repos/termux/termux-api/issues/466/events',
#     'html_url': 'https://github.com/termux/termux-api/issues/466',
#     'id': 1059276778,
#     'node_id': 'I_kwDOAkrq9c4_I0fq',
#     'number': 466,
#     'title': 'termux-api commands hang in terminal without any output',
#     'user': {'login': 'johnwuelk',
#      'id': 12553753,
#      'node_id': 'MDQ6VXNlcjEyNTUzNzUz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/12553753?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/johnwuelk',
#      'html_url': 'https://github.com/johnwuelk',
#      'followers_url': 'https://api.github.com/users/johnwuelk/followers',
#      'following_url': 'https://api.github.com/users/johnwuelk/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/johnwuelk/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/johnwuelk/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/johnwuelk/subscriptions',
#      'organizations_url': 'https://api.github.com/users/johnwuelk/orgs',
#      'repos_url': 'https://api.github.com/users/johnwuelk/repos',
#      'events_url': 'https://api.github.com/users/johnwuelk/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/johnwuelk/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 27,
#     'created_at': '2021-11-21T02:46:07Z',
#     'updated_at': '2024-04-24T20:41:56Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
# ...
#       'gists_url': 'https://api.github.com/users/MuhammadA15/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MuhammadA15/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MuhammadA15/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MuhammadA15/orgs',
#       'repos_url': 'https://api.github.com/users/MuhammadA15/repos',
#       'events_url': 'https://api.github.com/users/MuhammadA15/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MuhammadA15/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 789922547,
#       'node_id': 'R_kgDOLxVC8w',
#       'name': 'devops-playground',
#       'full_name': 'MuhammadA15/devops-playground',
#       'private': False,
#       'owner': {'login': 'MuhammadA15',
#        'id': 47173221,
#        'node_id': 'MDQ6VXNlcjQ3MTczMjIx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/47173221?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/MuhammadA15',
#        'html_url': 'https://github.com/MuhammadA15',
#        'followers_url': 'https://api.github.com/users/MuhammadA15/followers',
#        'following_url': 'https://api.github.com/users/MuhammadA15/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/MuhammadA15/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/MuhammadA15/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/MuhammadA15/subscriptions',
#        'organizations_url': 'https://api.github.com/users/MuhammadA15/orgs',
#        'repos_url': 'https://api.github.com/users/MuhammadA15/repos',
#        'events_url': 'https://api.github.com/users/MuhammadA15/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/MuhammadA15/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/MuhammadA15/devops-playground',
#       'description': 'Project for learning more about CI/CD pipelines and other devops/aws related services',
#       'fork': False,
#       'url': 'https://api.github.com/repos/MuhammadA15/devops-playground',
#       'forks_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/forks',
#       'keys_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/teams',
#       'hooks_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/hooks',
#       'issue_events_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/events',
#       'assignees_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/tags',
#       'blobs_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/languages',
#       'stargazers_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/stargazers',
#       'contributors_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/contributors',
#       'subscribers_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/subscribers',
#       'subscription_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/subscription',
#       'commits_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/merges',
#       'archive_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/downloads',
#       'issues_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/MuhammadA15/devops-playground/deployments',
#       'created_at': '2024-04-21T22:58:24Z',
#       'updated_at': '2024-04-24T02:12:24Z',
#       'pushed_at': '2024-04-24T20:41:25Z',
#       'git_url': 'git://github.com/MuhammadA15/devops-playground.git',
#       'ssh_url': 'git@github.com:MuhammadA15/devops-playground.git',
#       'clone_url': 'https://github.com/MuhammadA15/devops-playground.git',
#       'svn_url': 'https://github.com/MuhammadA15/devops-playground',
#       'homepage': None,
#       'size': 86,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/MuhammadA15/devops-playground/pulls/8'},
#      'html': {'href': 'https://github.com/MuhammadA15/devops-playground/pull/8'},
#      'issue': {'href': 'https://api.github.com/repos/MuhammadA15/devops-playground/issues/8'},
#      'comments': {'href': 'https://api.github.com/repos/MuhammadA15/devops-playground/issues/8/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/MuhammadA15/devops-playground/pulls/8/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/MuhammadA15/devops-playground/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/MuhammadA15/devops-playground/pulls/8/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/MuhammadA15/devops-playground/statuses/31fdb8e9e8c603e4aa5fe4874977926c9b520261'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056644',
#   'type': 'PushEvent',
#   'actor': {'id': 86586714,
#    'login': 'jan-beranek',
#    'display_login': 'jan-beranek',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jan-beranek',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86586714?'},
#   'repo': {'id': 791501345,
#    'name': 'trywopee-DEV/ebc222a4-fe1d-4af4-ae49-bf2930ec051a',
#    'url': 'https://api.github.com/repos/trywopee-DEV/ebc222a4-fe1d-4af4-ae49-bf2930ec051a'},
#   'payload': {'repository_id': 791501345,
#    'push_id': 18145227120,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/main',
#    'head': 'a302f17558b0d67d230e803280457f7ecea08d67',
#    'before': '0000000000000000000000000000000000000000',
#    'commits': [{'sha': 'a302f17558b0d67d230e803280457f7ecea08d67',
#      'author': {'email': '86586714+jan-beranek@users.noreply.github.com',
#       'name': 'Jan Beránek'},
#      'message': 'Initial commit',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/trywopee-DEV/ebc222a4-fe1d-4af4-ae49-bf2930ec051a/commits/a302f17558b0d67d230e803280457f7ecea08d67'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z',
#   'org': {'id': 151814201,
#    'login': 'trywopee-DEV',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/trywopee-DEV',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/151814201?'}},
#  {'id': '37789056674',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 737713978,
#    'name': 'liuzhileicf/weread2notion',
#    'url': 'https://api.github.com/repos/liuzhileicf/weread2notion'},
#   'payload': {'repository_id': 737713978,
#    'push_id': 18145227141,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a50198b12ec2c726e0149fc82daefc12a3ddee99',
#    'before': '639c43394afeeb837e11eb935ae25ee7f43538b3',
#    'commits': [{'sha': 'a50198b12ec2c726e0149fc82daefc12a3ddee99',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'add new cover',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/liuzhileicf/weread2notion/commits/a50198b12ec2c726e0149fc82daefc12a3ddee99'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056677',
#   'type': 'PushEvent',
#   'actor': {'id': 123976180,
#    'login': 'othmane-chaikhi',
#    'display_login': 'othmane-chaikhi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/othmane-chaikhi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/123976180?'},
#   'repo': {'id': 791501094,
#    'name': 'othmane-chaikhi/unix',
#    'url': 'https://api.github.com/repos/othmane-chaikhi/unix'},
#   'payload': {'repository_id': 791501094,
#    'push_id': 18145227146,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '228066ff3bf9dcaa2b38d06d8e3494ef42d1653a',
#    'before': '05270bbce30ccb252092454bdec21035b648e598',
#    'commits': [{'sha': '228066ff3bf9dcaa2b38d06d8e3494ef42d1653a',
#      'author': {'email': '123976180+othmane-chaikhi@users.noreply.github.com',
#       'name': 'Chaikhi Othmane'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/othmane-chaikhi/unix/commits/228066ff3bf9dcaa2b38d06d8e3494ef42d1653a'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056682',
#   'type': 'PushEvent',
#   'actor': {'id': 17126622,
#    'login': 'norellanac',
#    'display_login': 'norellanac',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/norellanac',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17126622?'},
#   'repo': {'id': 431221960,
#    'name': 'norellanac/myWebsite',
#    'url': 'https://api.github.com/repos/norellanac/myWebsite'},
#   'payload': {'repository_id': 431221960,
#    'push_id': 18145227151,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '260688099d43659e0eb7d4e95aa2206690d60591',
#    'before': 'd4bf75537a864e3538800ee59ddd5112a58554f7',
#    'commits': [{'sha': '260688099d43659e0eb7d4e95aa2206690d60591',
#      'author': {'email': '1005alexis@gmail.com', 'name': 'Alexis Orellana'},
#      'message': 'Updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/norellanac/myWebsite/commits/260688099d43659e0eb7d4e95aa2206690d60591'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056635',
#   'type': 'PushEvent',
#   'actor': {'id': 101478632,
#    'login': 'Ahmed9588406',
#    'display_login': 'Ahmed9588406',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ahmed9588406',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101478632?'},
#   'repo': {'id': 791500864,
#    'name': 'Ahmed9588406/intermediate-python',
#    'url': 'https://api.github.com/repos/Ahmed9588406/intermediate-python'},
#   'payload': {'repository_id': 791500864,
#    'push_id': 18145227123,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/Lists',
#    'head': '8e4795ed9b504db3fceeb44b11c8ff2ee813a472',
#    'before': '0000000000000000000000000000000000000000',
#    'commits': [{'sha': '8e4795ed9b504db3fceeb44b11c8ff2ee813a472',
#      'author': {'email': '101478632+Ahmed9588406@users.noreply.github.com',
#       'name': 'Ahmed'},
#      'message': 'Initial commit',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Ahmed9588406/intermediate-python/commits/8e4795ed9b504db3fceeb44b11c8ff2ee813a472'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056654',
#   'type': 'WatchEvent',
#   'actor': {'id': 52239427,
#    'login': 'sleroq',
#    'display_login': 'sleroq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sleroq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52239427?'},
#   'repo': {'id': 906022,
#    'name': 'gildas-lormeau/SingleFile',
#    'url': 'https://api.github.com/repos/gildas-lormeau/SingleFile'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056646',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 582291680,
#    'name': 'nuz007/hot',
#    'url': 'https://api.github.com/repos/nuz007/hot'},
#   'payload': {'repository_id': 582291680,
#    'push_id': 18145227122,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '19b9e413e01165b6f7d405321f224542b7d82dab',
#    'before': '617f0b21845ecf3732839a5a16e6d011564cc4df',
#    'commits': [{'sha': '19b9e413e01165b6f7d405321f224542b7d82dab',
#      'author': {'email': 'bot@github.com', 'name': 'bot'},
#      'message': '爬取热点',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nuz007/hot/commits/19b9e413e01165b6f7d405321f224542b7d82dab'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'},
#  {'id': '37789056638',
#   'type': 'PushEvent',
#   'actor': {'id': 37102945,
#    'login': 'AnriEU',
#    'display_login': 'AnriEU',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AnriEU',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37102945?'},
#   'repo': {'id': 569569539,
#    'name': 'AnriEU/tg',
#    'url': 'https://api.github.com/repos/AnriEU/tg'},
#   'payload': {'repository_id': 569569539,
#    'push_id': 18145227119,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '68e8c2a2cd399f8c5cd1dc3ed1d0685dc9036199',
#    'before': '585ab6ee5fc5cd63ab6b9bc4bbfa228ecf291d9f',
#    'commits': [{'sha': '68e8c2a2cd399f8c5cd1dc3ed1d0685dc9036199',
#      'author': {'email': 'tvwk2013@gmail.com', 'name': 'AnriEU'},
#      'message': 'Upload file commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AnriEU/tg/commits/68e8c2a2cd399f8c5cd1dc3ed1d0685dc9036199'}]},
#   'public': True,
#   'created_at': '2024-04-24T20:41:56Z'}]

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
#Especificando uma versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}
r = requests.get('https://api.github.com/versions', headers=headers)
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# <span style="font-size: 2em;">Obtendo dados dos repositórios</span>

# %%
#Especificando uma versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2024-01-28T17:12:00Z',
#   'pushed_at': '2024-03-14T15:40:19Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 26,
#   'stargazers_count': 12,
#   'watchers_count': 12,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 329,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 329,
#   'open_issues': 3,
#   'watchers': 12,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2024-04-16T10:52:31Z',
#   'pushed_at': '2024-03-13T17:28:44Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 1314,
#   'stargazers_count': 80,
#   'watchers_count': 80,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 31,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 12,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 31,
#   'open_issues': 12,
#   'watchers': 80,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2023-09-27T22:07:43Z',
#   'pushed_at': '2024-02-12T18:18:28Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 345,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2023-12-19T17:38:03Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 23,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 23,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2024-04-06T20:53:06Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1132,
#   'watchers_count': 1132,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1049,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1049,
#   'open_issues': 11,
#   'watchers': 1132,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2024-04-16T08:35:00Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 7,
#   'watchers_count': 7,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 0,
#   'watchers': 7,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-03-09T16:39:20Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 94,
#   'watchers_count': 94,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 67,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 67,
#   'open_issues': 14,
#   'watchers': 94,
#   'default_branch': 'master'},
#  {'id': 429297502,
#   'node_id': 'R_kgDOGZaPXg',
#   'name': 'amazon-codeguru-profiler-for-spark',
#   'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'description': 'A Spark plugin for CPU and memory profiling',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#   'created_at': '2021-11-18T04:37:55Z',
#   'updated_at': '2023-07-14T20:17:43Z',
#   'pushed_at': '2024-03-26T05:38:29Z',
#   'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#   'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'homepage': '',
#   'size': 2352,
#   'stargazers_count': 17,
#   'watchers_count': 17,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 11,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 11,
#   'open_issues': 1,
#   'watchers': 17,
#   'default_branch': 'main'},
#  {'id': 397426400,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTc0MjY0MDA=',
#   'name': 'amazon-frustration-free-setup-certification-tool',
# ...
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/deployments',
#   'created_at': '2014-12-05T18:51:43Z',
#   'updated_at': '2024-02-14T22:31:06Z',
#   'pushed_at': '2023-07-30T04:40:47Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-java.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-java.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-java.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 13957,
#   'stargazers_count': 54,
#   'watchers_count': 54,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 51,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 15,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 51,
#   'open_issues': 15,
#   'watchers': 54,
#   'default_branch': 'master'},
#  {'id': 26331269,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMzMTI2OQ==',
#   'name': 'amazon-pay-sdk-php',
#   'full_name': 'amzn/amazon-pay-sdk-php',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'description': 'Amazon Pay PHP SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/deployments',
#   'created_at': '2014-11-07T18:00:47Z',
#   'updated_at': '2024-03-11T17:57:58Z',
#   'pushed_at': '2024-03-31T15:06:56Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-php.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-php.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-php.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 866,
#   'stargazers_count': 209,
#   'watchers_count': 209,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 92,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 37,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 92,
#   'open_issues': 37,
#   'watchers': 209,
#   'default_branch': 'master'},
#  {'id': 29757348,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTc1NzM0OA==',
#   'name': 'amazon-pay-sdk-python',
#   'full_name': 'amzn/amazon-pay-sdk-python',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-python',
#   'description': 'Amazon Pay Python SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-python/deployments',
#   'created_at': '2015-01-23T23:00:34Z',
#   'updated_at': '2024-03-08T06:26:24Z',
#   'pushed_at': '2024-02-23T18:53:05Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-python.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-python.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-python.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-python',
#   'homepage': '',
#   'size': 83,
#   'stargazers_count': 54,
#   'watchers_count': 54,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 38,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 9,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 38,
#   'open_issues': 9,
#   'watchers': 54,
#   'default_branch': 'master'}]

# %%
len(response.json())
# Out:
# 30

# %% [markdown]
# <span style="font-size: 2em;">Autentificação</span>

# %% [markdown]
# A autenticação em APIs é um processo que permite a verificação da identidade da pessoa usuária que está acessando os dados. Existem diferentes tipos de autenticação, cada um com suas características e formas de implementação. Os principais tipos de autenticação são:
#
# 1 - Autenticação por chave de API (API Key):
#
# Esse tipo de autenticação é o mais simples e comum. Nele, a API fornece uma chave de acesso exclusiva para cada pessoa usuária, que é usada como um "código de identificação". A chave é enviada junto com a requisição para a API e é verificada pelo servidor para permitir ou negar o acesso aos dados.
#
# 2 - Autenticação por token:
#
# Nesse tipo de autenticação, a API fornece um token de acesso para a pessoa usuária após a autenticação bem-sucedida, geralmente usando um login e senha. O token é um código que permite que a pessoa usuária acesse os recursos da API sem precisar enviar novamente suas credenciais. Ele pode ter um tempo de validade, e a pessoa usuária pode precisar solicitar um novo token após o vencimento.
#
# 3 - Autenticação por OAuth:
#
# O OAuth é um protocolo de autorização que permite que uma pessoa usuária conceda acesso a seus recursos em uma API, sem compartilhar suas credenciais de login com a aplicação de terceiros. Nesse tipo de autenticação, a pessoa usuária é redirecionada para a página de login da API para inserir suas credenciais. Depois, é solicitada à pessoa usuária a autorização para que a aplicação de terceiros acesse seus recursos. A autorização é concedida por meio de um token OAuth, que permite que a aplicação acesse apenas os recursos autorizados pela pessoa usuária.
#
# Algumas APIs que utilizam esses tipos de autenticação são:
#
# API da NASA: usa uma chave de API para autenticação e controle de acesso.
#
# API do GitHub: usa token de acesso para autenticação e controle de acesso aos recursos.
#
# API do Spotify: usa OAuth para autenticação e autorização de acesso aos recursos.

# %%
# Dados sensiveis - TOKEN -
from scripts import config

# %%
# Out:
# ['/home/igor/Documentos/projeto_Request/scripts/notebook', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/home/igor/Documentos/projeto_Request/venv/lib/python3.10/site-packages', '/home/igor/Documentos/projeto_Request', '/home/igor/Documentos/projeto_Request']

# %%
access_token = config.TOKEN
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# <span style="font-size: 2em;">Paginação</span>

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []
for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/.github',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/.github',
#    'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/.github/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#    'created_at': '2019-02-18T18:59:22Z',
#    'updated_at': '2024-01-28T17:12:00Z',
#    'pushed_at': '2024-03-14T15:40:19Z',
#    'git_url': 'git://github.com/amzn/.github.git',
#    'ssh_url': 'git@github.com:amzn/.github.git',
#    'clone_url': 'https://github.com/amzn/.github.git',
#    'svn_url': 'https://github.com/amzn/.github',
#    'homepage': None,
#    'size': 26,
#    'stargazers_count': 12,
#    'watchers_count': 12,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 329,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 329,
#    'open_issues': 3,
#    'watchers': 12,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 492978607,
#    'node_id': 'R_kgDOHWJBrw',
#    'name': 'ads-advanced-tools-docs',
#    'full_name': 'amzn/ads-advanced-tools-docs',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#    'created_at': '2022-05-16T19:49:03Z',
#    'updated_at': '2024-04-16T10:52:31Z',
#    'pushed_at': '2024-03-13T17:28:44Z',
#    'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#    'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#    'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#    'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#    'size': 1314,
#    'stargazers_count': 80,
#    'watchers_count': 80,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 31,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 12,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#    'visibility': 'public',
#    'forks': 31,
#    'open_issues': 12,
#    'watchers': 80,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 674005216,
#    'node_id': 'R_kgDOKCyA4A',
#    'name': 'ads-pao-amznjs-gtm-template',
#    'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#    'created_at': '2023-08-02T23:41:56Z',
#    'updated_at': '2023-09-27T22:07:43Z',
#    'pushed_at': '2024-02-12T18:18:28Z',
#    'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#    'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'homepage': None,
#    'size': 345,
#    'stargazers_count': 1,
#    'watchers_count': 1,
#    'language': 'Smarty',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 1,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 41117941,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#    'name': 'alexa-coho',
#    'full_name': 'amzn/alexa-coho',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-coho',
#    'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-coho',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#    'created_at': '2015-08-20T20:42:31Z',
#    'updated_at': '2023-12-19T17:38:03Z',
#    'pushed_at': '2023-04-01T08:35:29Z',
#    'git_url': 'git://github.com/amzn/alexa-coho.git',
#    'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#    'clone_url': 'https://github.com/amzn/alexa-coho.git',
#    'svn_url': 'https://github.com/amzn/alexa-coho',
#    'homepage': None,
#    'size': 209,
#    'stargazers_count': 63,
#    'watchers_count': 63,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 23,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 4,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 23,
#    'open_issues': 4,
#    'watchers': 63,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 39471546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#    'name': 'alexa-skills-kit-js',
#    'full_name': 'amzn/alexa-skills-kit-js',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#    'created_at': '2015-07-21T21:46:48Z',
#    'updated_at': '2024-04-06T20:53:06Z',
#    'pushed_at': '2020-10-01T06:10:20Z',
#    'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#    'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#    'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#    'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'homepage': 'http://developer.amazon.com/ask',
#    'size': 8827,
#    'stargazers_count': 1132,
#    'watchers_count': 1132,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1049,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 11,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1049,
#    'open_issues': 11,
#    'watchers': 1132,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 495519526,
#    'node_id': 'R_kgDOHYkHJg',
#    'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#    'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#    'created_at': '2022-05-23T17:59:56Z',
#    'updated_at': '2024-04-16T08:35:00Z',
#    'pushed_at': '2022-05-23T21:20:34Z',
#    'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 7,
#    'watchers_count': 7,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 0,
#    'watchers': 7,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 61315875,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#    'name': 'amazon-advertising-api-php-sdk',
#    'full_name': 'amzn/amazon-advertising-api-php-sdk',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#    'created_at': '2016-06-16T18:16:46Z',
#    'updated_at': '2024-03-09T16:39:20Z',
#    'pushed_at': '2020-09-20T17:25:48Z',
#    'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#    'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'homepage': '',
#    'size': 49,
#    'stargazers_count': 94,
#    'watchers_count': 94,
#    'language': 'PHP',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 67,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 14,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 67,
#    'open_issues': 14,
#    'watchers': 94,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 429297502,
#    'node_id': 'R_kgDOGZaPXg',
#    'name': 'amazon-codeguru-profiler-for-spark',
#    'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'description': 'A Spark plugin for CPU and memory profiling',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
# ...
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/deployments',
#    'created_at': '2019-10-04T17:54:21Z',
#    'updated_at': '2024-03-20T15:34:11Z',
#    'pushed_at': '2024-03-20T15:34:06Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-bacnet.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-bacnet.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-bacnet.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-bacnet',
#    'homepage': None,
#    'size': 56,
#    'stargazers_count': 27,
#    'watchers_count': 27,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 14,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 19,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 14,
#    'open_issues': 19,
#    'watchers': 27,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 212873469,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzM0Njk=',
#    'name': 'zeek-plugin-enip',
#    'full_name': 'amzn/zeek-plugin-enip',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zeek-plugin-enip',
#    'description': 'Zeek network security monitor plugin that enables parsing of the Ethernet/IP and Common Industrial Protocol standards',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zeek-plugin-enip',
#    'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/deployments',
#    'created_at': '2019-10-04T17:56:40Z',
#    'updated_at': '2024-03-20T15:33:41Z',
#    'pushed_at': '2024-03-20T15:33:37Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-enip.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-enip.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-enip.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-enip',
#    'homepage': None,
#    'size': 59,
#    'stargazers_count': 43,
#    'watchers_count': 43,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 14,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 14,
#    'open_issues': 0,
#    'watchers': 43,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 212873911,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzM5MTE=',
#    'name': 'zeek-plugin-profinet',
#    'full_name': 'amzn/zeek-plugin-profinet',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zeek-plugin-profinet',
#    'description': 'Zeek network security monitor plugin that enables parsing of the Profinet protocol',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet',
#    'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/deployments',
#    'created_at': '2019-10-04T17:59:03Z',
#    'updated_at': '2024-03-06T09:14:42Z',
#    'pushed_at': '2024-03-21T01:09:34Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-profinet.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-profinet.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-profinet.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-profinet',
#    'homepage': None,
#    'size': 33,
#    'stargazers_count': 26,
#    'watchers_count': 26,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 18,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 18,
#    'open_issues': 2,
#    'watchers': 26,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}}]]

# %%
len(repos_list[3])
# Out:
# 30

# %% [markdown]
# # Nome dos repositórios

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/.github',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/.github',
#    'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/.github/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#    'created_at': '2019-02-18T18:59:22Z',
#    'updated_at': '2024-01-28T17:12:00Z',
#    'pushed_at': '2024-03-14T15:40:19Z',
#    'git_url': 'git://github.com/amzn/.github.git',
#    'ssh_url': 'git@github.com:amzn/.github.git',
#    'clone_url': 'https://github.com/amzn/.github.git',
#    'svn_url': 'https://github.com/amzn/.github',
#    'homepage': None,
#    'size': 26,
#    'stargazers_count': 12,
#    'watchers_count': 12,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 329,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 329,
#    'open_issues': 3,
#    'watchers': 12,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 492978607,
#    'node_id': 'R_kgDOHWJBrw',
#    'name': 'ads-advanced-tools-docs',
#    'full_name': 'amzn/ads-advanced-tools-docs',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#    'created_at': '2022-05-16T19:49:03Z',
#    'updated_at': '2024-04-16T10:52:31Z',
#    'pushed_at': '2024-03-13T17:28:44Z',
#    'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#    'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#    'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#    'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#    'size': 1314,
#    'stargazers_count': 80,
#    'watchers_count': 80,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 31,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 12,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#    'visibility': 'public',
#    'forks': 31,
#    'open_issues': 12,
#    'watchers': 80,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 674005216,
#    'node_id': 'R_kgDOKCyA4A',
#    'name': 'ads-pao-amznjs-gtm-template',
#    'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#    'created_at': '2023-08-02T23:41:56Z',
#    'updated_at': '2023-09-27T22:07:43Z',
#    'pushed_at': '2024-02-12T18:18:28Z',
#    'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#    'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'homepage': None,
#    'size': 345,
#    'stargazers_count': 1,
#    'watchers_count': 1,
#    'language': 'Smarty',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 1,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 41117941,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#    'name': 'alexa-coho',
#    'full_name': 'amzn/alexa-coho',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-coho',
#    'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-coho',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#    'created_at': '2015-08-20T20:42:31Z',
#    'updated_at': '2023-12-19T17:38:03Z',
#    'pushed_at': '2023-04-01T08:35:29Z',
#    'git_url': 'git://github.com/amzn/alexa-coho.git',
#    'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#    'clone_url': 'https://github.com/amzn/alexa-coho.git',
#    'svn_url': 'https://github.com/amzn/alexa-coho',
#    'homepage': None,
#    'size': 209,
#    'stargazers_count': 63,
#    'watchers_count': 63,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 23,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 4,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 23,
#    'open_issues': 4,
#    'watchers': 63,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 39471546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#    'name': 'alexa-skills-kit-js',
#    'full_name': 'amzn/alexa-skills-kit-js',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#    'created_at': '2015-07-21T21:46:48Z',
#    'updated_at': '2024-04-06T20:53:06Z',
#    'pushed_at': '2020-10-01T06:10:20Z',
#    'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#    'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#    'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#    'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'homepage': 'http://developer.amazon.com/ask',
#    'size': 8827,
#    'stargazers_count': 1132,
#    'watchers_count': 1132,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1049,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 11,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1049,
#    'open_issues': 11,
#    'watchers': 1132,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 495519526,
#    'node_id': 'R_kgDOHYkHJg',
#    'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#    'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#    'created_at': '2022-05-23T17:59:56Z',
#    'updated_at': '2024-04-16T08:35:00Z',
#    'pushed_at': '2022-05-23T21:20:34Z',
#    'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 7,
#    'watchers_count': 7,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 0,
#    'watchers': 7,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 61315875,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#    'name': 'amazon-advertising-api-php-sdk',
#    'full_name': 'amzn/amazon-advertising-api-php-sdk',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#    'created_at': '2016-06-16T18:16:46Z',
#    'updated_at': '2024-03-09T16:39:20Z',
#    'pushed_at': '2020-09-20T17:25:48Z',
#    'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#    'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'homepage': '',
#    'size': 49,
#    'stargazers_count': 94,
#    'watchers_count': 94,
#    'language': 'PHP',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 67,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 14,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 67,
#    'open_issues': 14,
#    'watchers': 94,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 429297502,
#    'node_id': 'R_kgDOGZaPXg',
#    'name': 'amazon-codeguru-profiler-for-spark',
#    'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'description': 'A Spark plugin for CPU and memory profiling',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
# ...
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-bacnet/deployments',
#    'created_at': '2019-10-04T17:54:21Z',
#    'updated_at': '2024-03-20T15:34:11Z',
#    'pushed_at': '2024-03-20T15:34:06Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-bacnet.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-bacnet.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-bacnet.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-bacnet',
#    'homepage': None,
#    'size': 56,
#    'stargazers_count': 27,
#    'watchers_count': 27,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 14,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 19,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 14,
#    'open_issues': 19,
#    'watchers': 27,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 212873469,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzM0Njk=',
#    'name': 'zeek-plugin-enip',
#    'full_name': 'amzn/zeek-plugin-enip',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zeek-plugin-enip',
#    'description': 'Zeek network security monitor plugin that enables parsing of the Ethernet/IP and Common Industrial Protocol standards',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zeek-plugin-enip',
#    'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-enip/deployments',
#    'created_at': '2019-10-04T17:56:40Z',
#    'updated_at': '2024-03-20T15:33:41Z',
#    'pushed_at': '2024-03-20T15:33:37Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-enip.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-enip.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-enip.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-enip',
#    'homepage': None,
#    'size': 59,
#    'stargazers_count': 43,
#    'watchers_count': 43,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 14,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['ics-security', 'security-tools', 'zeek', 'zeek-package'],
#    'visibility': 'public',
#    'forks': 14,
#    'open_issues': 0,
#    'watchers': 43,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 212873911,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI4NzM5MTE=',
#    'name': 'zeek-plugin-profinet',
#    'full_name': 'amzn/zeek-plugin-profinet',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/zeek-plugin-profinet',
#    'description': 'Zeek network security monitor plugin that enables parsing of the Profinet protocol',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet',
#    'forks_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/zeek-plugin-profinet/deployments',
#    'created_at': '2019-10-04T17:59:03Z',
#    'updated_at': '2024-03-06T09:14:42Z',
#    'pushed_at': '2024-03-21T01:09:34Z',
#    'git_url': 'git://github.com/amzn/zeek-plugin-profinet.git',
#    'ssh_url': 'git@github.com:amzn/zeek-plugin-profinet.git',
#    'clone_url': 'https://github.com/amzn/zeek-plugin-profinet.git',
#    'svn_url': 'https://github.com/amzn/zeek-plugin-profinet',
#    'homepage': None,
#    'size': 33,
#    'stargazers_count': 26,
#    'watchers_count': 26,
#    'language': 'Zeek',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 18,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': {'key': 'bsd-3-clause',
#     'name': 'BSD 3-Clause "New" or "Revised" License',
#     'spdx_id': 'BSD-3-Clause',
#     'url': 'https://api.github.com/licenses/bsd-3-clause',
#     'node_id': 'MDc6TGljZW5zZTU='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 18,
#    'open_issues': 2,
#    'watchers': 26,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}}]]

# %%
repos_list[0][2]['name']
# fazer um laço para percorrer e guardar só o nome
# Out:
# 'ads-pao-amznjs-gtm-template'

# %%
repos_names = []

for page in repos_list:
    for repo in page:
        repos_names.append(repo['name'])

print(repos_names)
# Out:
# ['.github', 'ads-advanced-tools-docs', 'ads-pao-amznjs-gtm-template', 'alexa-coho', 'alexa-skills-kit-js', 'amazon-ads-advertiser-audience-normalization-sdk-py', 'amazon-advertising-api-php-sdk', 'amazon-codeguru-profiler-for-spark', 'amazon-frustration-free-setup-certification-tool', 'amazon-hub-counter-api-docs', 'amazon-hub-counter-api-samples', 'amazon-hub-counter-sdk-java', 'amazon-hub-support', 'amazon-instant-access-sdk-java', 'amazon-instant-access-sdk-net', 'amazon-instant-access-sdk-php', 'amazon-instant-access-sdk-ruby', 'amazon-launcher-integration-cordova-plugin', 'amazon-marketing-stream-examples', 'amazon-mcf-plugin-for-magento-1', 'amazon-multi-token-completion', 'amazon-nearest-neighbor-through-ecc', 'amazon-pay-api-sdk-dotnet', 'amazon-pay-api-sdk-java', 'amazon-pay-api-sdk-nodejs', 'amazon-pay-api-sdk-php', 'amazon-pay-sdk-csharp', 'amazon-pay-sdk-java', 'amazon-pay-sdk-php', 'amazon-pay-sdk-python', 'amazon-pay-sdk-ruby', 'amazon-pay-sdk-samples', 'amazon-payment-files-tools', 'amazon-payments-magento-2-plugin', 'amazon-ray', 'amazon-s3-gst-plugin', 'amazon-sidewalk-android-samples', 'amazon-sidewalk-ios-samples', 'amazon-succinct-doc-representation', 'amazon-template-library', 'amazon-weak-ner-needle', 'amigitenough', 'amzn-drivers', 'amzn-ec2-ena-utilities', 'auction-gym', 'augment-the-pairs-wacv2024', 'autotrail', 'aws-apigateway-client-lib', 'aws-sigv4-signing-samples', 'awsssmchaosrunner', 'basis-point-sets', 'buy-with-prime-automate-tenant-validation', 'buy-with-prime-cdk-constructs', 'buy-with-prime-event-accelerator', 'buy-with-prime-monitoring-sample-cdk', 'buy-with-prime-oauth-handler-ec2', 'buy-with-prime-saas-integration', 'chalet-charging-location-for-electric-trucks', 'computer-vision-basics-in-microsoft-excel', 'confident-sinkhorn-allocation', 'convolutional-handwriting-gan', 'cosearcher', 'credence-to-causal-estimation', 'data-jack-knife', 'debiased-balanced-interleaving', 'differential-privacy-bayesian-optimization', 'distance-assistant', 'drs-sample-android-app', 'drs-sample-ios-app', 'emukit-playground', 'eslint-plugin-no-date-parsing', 'exoplayer-amazon-port', 'explainable-text-vqa', 'extremely-efficient-query-encoder', 'faithful-data2text-cycle-training', 'fashion-attribute-disentanglement', 'fire-app-builder', 'firetv-sample-touch-app', 'ftv-integration-sdk-sample-app', 'ftv-livetv-sample-tv-app', 'gameon-sample-game-unity', 'gameon-starter-kit-unity', 'git-commit-template', 'glad', 'golang-gitoperations', 'halo-third-party-sdk-for-java', 'halo-third-party-sdk-for-node-js', 'halo-third-party-sdk-for-python', 'hawktracer', 'image-misspell-coling2020', 'image-to-recipe-transformers', 'informative-diverse-hard-negative-sampling', 'ion-object-mapper-dotnet', 'jekyll-doc-project', 'kqr', 'login-with-amazon-oscommerce', 'login-with-amazon-wordpress', 'merlin-on-demand-callgraph', 'metalearn-leap', 'milan', 'mrc-net-6d-pose', 'multiconer-baseline', 'multilingual-keyphrase-generation', 'multimodal-affinities', 'MXFusion', 'nimbus-jose-jwt_aws-kms-extension', 'node-jose_aws-kms-extension', 'openapi-swift-code-generate', 'orthogonal-additive-gaussian-processes', 'oss-attribution-builder', 'oss-contribution-tracker', 'oss-dashboard', 'pecos', 'pretraining-or-self-training', 'python-jose_aws-kms-extension', 'rdma-core', 'refuel-open-domain-qa', 'rete-thewebconf-2022', 'rheoceros', 'robotiq-gripper-interface', 'sample-fire-tv-app-video-skill', 'selling-partner-api-docs', 'selling-partner-api-models', 'selling-partner-api-samples', 'seqzero', 'service-model-swift-code-generate', 'sketch-constructor', 'smoke-aws', 'smoke-aws-credentials', 'smoke-aws-generate', 'smoke-aws-support', 'smoke-dynamodb', 'smoke-framework', 'smoke-framework-application-generate', 'smoke-framework-examples', 'smoke-http', 'sparse-vqvae', 'ss-aga-kgc', 'sto-transformer', 'style-dictionary', 'supply-chain-simulation-environment', 'tiny-attribution-generator', 'trans-encoder', 'user-satisfaction-modeling', 'workspace-resolver', ...

# %%
len(repos_names)
# Out:
# 150

# %% [markdown]
# # Linguagens dos repositórios

# %%
repos_list[0][2]['language']
# fazer um laço para percorrer e guardar só o linguagem
# Out:
# 'Smarty'

# %%
repos_language = []

for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

print(repos_language)
# Out:
# [None, None, 'Smarty', 'JavaScript', None, 'Python', 'PHP', 'Java', 'Python', 'CSS', 'Java', 'Java', 'PowerShell', 'Java', 'C#', 'PHP', 'Ruby', 'JavaScript', 'Python', 'PHP', 'Python', 'Jupyter Notebook', 'C#', 'Java', 'JavaScript', 'PHP', 'C#', 'Java', 'PHP', 'Python', 'Ruby', 'PHP', 'Kotlin', 'PHP', 'Python', 'C', None, 'Swift', 'Python', 'C++', 'Python', 'Go', 'C', 'Python', 'Jupyter Notebook', 'Python', 'Python', None, 'Java', 'Kotlin', 'Python', 'JavaScript', 'TypeScript', 'Python', 'TypeScript', 'JavaScript', 'TypeScript', 'Python', None, 'Jupyter Notebook', 'Python', 'Python', 'Python', 'Java', 'Jupyter Notebook', 'Python', 'Python', 'Java', 'Objective-C', 'JavaScript', 'TypeScript', 'Java', None, 'Python', 'Python', 'Python', 'Java', 'Java', 'Kotlin', 'Java', 'C#', 'C#', 'JavaScript', 'JavaScript', 'Go', 'Java', 'TypeScript', 'Python', 'C++', None, 'Python', 'Python', 'C#', 'HTML', None, 'PHP', 'PHP', 'JavaScript', 'Python', 'Scala', 'Python', 'Python', 'Python', 'Python', 'Python', 'Java', 'TypeScript', 'Swift', 'Python', 'TypeScript', 'TypeScript', 'Ruby', 'Python', 'Python', 'Python', 'C', 'Python', 'Python', 'Python', 'C++', 'Java', None, 'Mustache', 'Python', 'Python', 'Swift', 'JavaScript', 'Swift', 'Swift', 'Swift', 'Swift', 'Swift', 'Swift', 'Swift', 'Swift', 'Swift', 'Python', 'Python', 'Python', 'JavaScript', 'Python', 'TypeScript', 'Python', 'Python', 'JavaScript', 'Python', 'Python', 'Zeek', 'Zeek', 'Zeek']

# %%
len(repos_language)
# Out:
# 150

# %% [markdown]
# # Criando um DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_names
dados_amz['language'] = repos_language

# %%
dados_amz
# Out:
#                  repository_name    language
# 0                        .github        None
# 1        ads-advanced-tools-docs        None
# 2    ads-pao-amznjs-gtm-template      Smarty
# 3                     alexa-coho  JavaScript
# 4            alexa-skills-kit-js        None
# ..                           ...         ...
# 145                       ws-vae      Python
# 146                         xfer      Python
# 147           zeek-plugin-bacnet        Zeek
# 148             zeek-plugin-enip        Zeek
# 149         zeek-plugin-profinet        Zeek
#
# [150 rows x 2 columns]

# %% [markdown]
# # Salvando o DataFrame

# %%
dados_amz.to_csv('external_data/amazon.csv')

# %% [markdown]
# # Armazenando os dados

# %% [markdown]
# ### Criando repositórios com POST

# %%
access_token = config.TOKEN
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'

url = f'{api_base_url}/user/repos'
url
# Out:
# 'https://api.github.com/user/repos'

# %%
data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens de prog da Amazon, projeto Engenharia de dados Alura',
    'private': False
}

response = requests.post(url, json=data, headers=headers)
response.status_code
# Out:
# 422

# %% [markdown]
# # Formato do arquivo

# %%
import base64

# %%
with open('external_data/amazon.csv', 'rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content)
#nosso arquivo foi codificado e está salvo na variável encoded_content. Agora, podemos fazer o upload dele para nosso repositório no GitHub.

# %% [markdown]
# # Upload de arquivo com PUT

# %%
api_base_url = 'https://api.github.com'
username = 'igoriafxd'
repo = 'linguagens-utilizadas'
path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/igoriafxd/linguagens-utilizadas/contents/external_data/amazon.csv'

# %%
data = {
    'message': 'Adicionando um novo arquivo', #commit
    'content': encoded_content.decode('utf-8')
}

response = requests.put(url, json=data, headers=headers)
response.status_code
# Out:
# 201

# %% [markdown]
# # Ultilizando o DELETE no repositorio

# %%
access_token = config.TOKEN
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}
owner = 'igoriafxd'
repo = 'linguagens-utilizadas'
url = f'https://api.github.com/repos/{owner}/{repo}'

response = requests.delete(url, headers=headers)
print(f"{response.status_code}")
# Out:
# 204
